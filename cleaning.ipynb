# %% [markdown]
# # Nettoyage des données
# -----------------------------------------------------------------------------------
# ## 1 - Chargement des données scraper du GitHub
# -----------------------------------------------------------------------------------

# %%
import pandas as pd
import numpy as np
import re
import requests
from collections import Counter
import time

# %%
df = pd.read_csv('repositories2023-01-01_2023-06-30_100PerDay.csv')
df.head()
# Out:
#                          name
# 0            learn-javascript  \
# 1                  NetCodeTop
# 2                    LinksHub
# 3              90DaysOfDevOps
# 4  JavaScriptCodingChallenges
#
#                                                  url
# 0         https://github.com/sumn2u/learn-javascript  \
# 1        https://github.com/bianchenglequ/NetCodeTop
# 2           https://github.com/rupali-codes/LinksHub
# 3  https://github.com/LondheShubham153/90DaysOfDe...
# 4  https://github.com/jahidulislamzim/JavaScriptC...
#
#                                          description  stars
# 0                     A book that teaches JavaScript    635  \
# 1             收集GitHub上有关.Net、.NetCore有趣、有用、热门的开源项目。    589
# 2  LinksHub aims to provide developers with acces...    359
# 3  This repository is a Challenge for the DevOps ...    352
# 4  Hello JavaScript code newbie! In this reposito...    221
#
#              created_at    language  forks  watchers  open_issues
# 0  2023-01-01T15:16:26Z        HTML     32       635            1  \
# 1  2023-01-01T16:52:06Z         NaN    107       589            1
# 2  2023-01-01T18:55:44Z  TypeScript    305       359           99
# 3  2023-01-01T11:41:21Z      Python   2274       352           54
# 4  2023-01-01T14:04:36Z         NaN     41       221            0
#
#               owner
# 0            sumn2u
# 1     bianchenglequ
# 2      rupali-codes
# 3  LondheShubham153
# 4   jahidulislamzim

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18100 entries, 0 to 18099
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   name         18099 non-null  object
#  1   url          18100 non-null  object
#  2   description  15239 non-null  object
#  3   stars        18100 non-null  int64
#  4   created_at   18100 non-null  object
#  5   language     15600 non-null  object
#  6   forks        18100 non-null  int64
#  7   watchers     18100 non-null  int64
#  8   open_issues  18100 non-null  int64
#  9   owner        18100 non-null  object
# dtypes: int64(4), object(6)
# memory usage: 1.4+ MB

# %% [markdown]
# -----------------------------------------------------------------------------------
# ## 2 - Traitement des valeurs manquantes
# -----------------------------------------------------------------------------------

# %%
# poucentage des valeurs manquantes par colonne > 0%
print('Poucentage des valeurs manquantes par colonne \n',round(df.isnull().sum() / len(df) * 100, 2))
# Out:
# Poucentage des valeurs manquantes par colonne
#  name            0.01
# url             0.00
# description    15.81
# stars           0.00
# created_at      0.00
# language       13.81
# forks           0.00
# watchers        0.00
# open_issues     0.00
# owner           0.00
# dtype: float64

# %% [markdown]
# -----------------------------------------------------------------------------------
# ### En remplis le nom monquant car nous allons l'utilisée pour déduire une déscription
# -----------------------------------------------------------------------------------

# %%
# afficher la ligne avec la valeur du name manquante
df[df['name'].isnull()]
# Out:
#       name                                  url description  stars
# 17154  NaN  https://github.com/GladiatorVS/null         NaN     17  \
#
#                  created_at language  forks  watchers  open_issues
# 17154  2023-06-21T11:12:44Z      NaN      0        17            0  \
#
#              owner
# 17154  GladiatorVS

# %%
# remplire le nom manquant par la partie de l'url qui suit le dernier '/'
df['name'] = df['name'].fillna(df['url'].str.split('/').str[-1])
# afficher la ligne avec l'indexe 17154
df.iloc[17154]
# Out:
# name                                          null
# url            https://github.com/GladiatorVS/null
# description                                    NaN
# stars                                           17
# created_at                    2023-06-21T11:12:44Z
# language                                       NaN
# forks                                            0
# watchers                                        17
# open_issues                                      0
# owner                                  GladiatorVS
# Name: 17154, dtype: object

# %% [markdown]
# -----------------------------------------------------------------------------------
# ### En utilise le nom pour déduire une déscription provisoire vue que les déscriptions non pas notre variable target mais peuvent étre utils pour l'analyse prochaine
# -----------------------------------------------------------------------------------

# %%
def generate_description(repository_name):
    # Split the name into words based on hyphens and uppercase letters
    
    words = re.findall(r'[A-Z][a-z0-9]*|[a-z0-9]+', repository_name)
    description = 'repository of ' + ' '.join(words).capitalize()
    
    return description

# %%
# les index des lignes avec des descriptions manquantes
null_descs_index = df[df['description'].isnull()].index
df[df['description'].isnull()].head()
# Out:
#                                                  name
# 22                               DoomInUnityInspector  \
# 26                     real_time_vehicle_tracking_app
# 35  Turkiye-deki-Acik-Veri-Portallari-Open-Data-Po...
# 49                                 SpeakerDiarization
# 52                         luchanos_oxford_university
#
#                                                   url description  stars
# 22    https://github.com/xabblll/DoomInUnityInspector         NaN     87  \
# 26  https://github.com/mostafaemara/real_time_vehi...         NaN     74
# 35  https://github.com/ozancanozdemir/Turkiye-deki...         NaN     54
# 49  https://github.com/mahdeslami11/SpeakerDiariza...         NaN     40
# 52  https://github.com/luchanos/luchanos_oxford_un...         NaN     38
#
#               created_at language  forks  watchers  open_issues
# 22  2023-01-01T20:02:11Z       C#      7        87            0  \
# 26  2023-01-01T14:42:23Z     Dart     35        74            0
# 35  2023-01-01T19:41:09Z      NaN      1        54            0
# 49  2023-01-01T16:47:08Z   Python      0        40            0
# 52  2023-01-01T13:39:00Z   Python     12        38            4
#
#              owner
# 22         xabblll
# 26    mostafaemara
# 35  ozancanozdemir
# 49    mahdeslami11
# 52        luchanos

# %%
# appliquer la fonction generate_description sur la colonne name des lignes avec des descriptions manquantes
df.loc[df['description'].isnull(), 'description'] = df.loc[df['description'].isnull(), 'name'].apply(generate_description)
# afficher les lignes avec les indexes null_descs_index
df.loc[null_descs_index].head()
# Out:
#                                                  name
# 22                               DoomInUnityInspector  \
# 26                     real_time_vehicle_tracking_app
# 35  Turkiye-deki-Acik-Veri-Portallari-Open-Data-Po...
# 49                                 SpeakerDiarization
# 52                         luchanos_oxford_university
#
#                                                   url
# 22    https://github.com/xabblll/DoomInUnityInspector  \
# 26  https://github.com/mostafaemara/real_time_vehi...
# 35  https://github.com/ozancanozdemir/Turkiye-deki...
# 49  https://github.com/mahdeslami11/SpeakerDiariza...
# 52  https://github.com/luchanos/luchanos_oxford_un...
#
#                                           description  stars
# 22              repository of Doom in unity inspector     87  \
# 26       repository of Real time vehicle tracking app     74
# 35  repository of Turkiye deki acik veri portallar...     54
# 49                  repository of Speaker diarization     40
# 52           repository of Luchanos oxford university     38
#
#               created_at language  forks  watchers  open_issues
# 22  2023-01-01T20:02:11Z       C#      7        87            0  \
# 26  2023-01-01T14:42:23Z     Dart     35        74            0
# 35  2023-01-01T19:41:09Z      NaN      1        54            0
# 49  2023-01-01T16:47:08Z   Python      0        40            0
# 52  2023-01-01T13:39:00Z   Python     12        38            4
#
#              owner
# 22         xabblll
# 26    mostafaemara
# 35  ozancanozdemir
# 49    mahdeslami11
# 52        luchanos

# %%
print('Poucentage des valeurs manquantes par colonne \n',round(df.isnull().sum() / len(df) * 100, 2))
# Out:
# Poucentage des valeurs manquantes par colonne
#  name            0.00
# url             0.00
# description     0.00
# stars           0.00
# created_at      0.00
# language       13.81
# forks           0.00
# watchers        0.00
# open_issues     0.00
# owner           0.00
# dtype: float64

# %% [markdown]
# -----------------------------------------------------------------------------------
# ### Pour la valeur target language : si l'analyse necissite l'extention dans les fichiers des repos avec pas de langage de programattion, on les scrap, sinon on les supprime
# -----------------------------------------------------------------------------------

# %%
# afficher les lignes avec des valeurs manquantes dans la colonne language
df[df['language'].isnull()].head()
# Out:
#                           name
# 1                   NetCodeTop  \
# 4   JavaScriptCodingChallenges
# 23         awesome-playgrounds
# 25                    xingtian
# 29              90DaysOfDevOps
#
#                                                   url
# 1         https://github.com/bianchenglequ/NetCodeTop  \
# 4   https://github.com/jahidulislamzim/JavaScriptC...
# 23  https://github.com/marcosnils/awesome-playgrounds
# 25                 https://github.com/hjyvip/xingtian
# 29        https://github.com/rajani103/90DaysOfDevOps
#
#                                           description  stars
# 1              收集GitHub上有关.Net、.NetCore有趣、有用、热门的开源项目。    589  \
# 4   Hello JavaScript code newbie! In this reposito...    221
# 23                        List of awesome playgrounds     85
# 25  VPN/proxy WIKI .Find the best VPN/proxy 免费的VPN...     77
# 29                                     90DaysOfDevOps     68
#
#               created_at language  forks  watchers  open_issues
# 1   2023-01-01T16:52:06Z      NaN    107       589            1  \
# 4   2023-01-01T14:04:36Z      NaN     41       221            0
# 23  2023-01-01T23:10:24Z      NaN      7        85            0
# 25  2023-01-01T12:12:01Z      NaN      7        77            0
# 29  2023-01-01T16:03:57Z      NaN     55        68            0
#
#               owner
# 1     bianchenglequ
# 4   jahidulislamzim
# 23       marcosnils
# 25           hjyvip
# 29        rajani103

# %%
def get_most_common_file_type(repo_url):
    headers = {"Accept": "application/vnd.github.v3+json"}
    retries = 3
    delay = 1

    for _ in range(retries):
        try:
            response = requests.get(f"{repo_url}/contents", headers=headers)
            if response.status_code == 200:
                files = response.json()
                file_types = [file['name'].split('.')[-1] for file in files if '.' in file['name']]
                most_common_file_type = Counter(file_types).most_common(1)
                return most_common_file_type[0][0] if most_common_file_type else 'No files with extensions'
            else:
                return 'Error: Unable to retrieve repository contents'
        except requests.exceptions.RequestException:
            print("Connection error. Retrying after a delay...")
            time.sleep(delay)
            continue

    return 'Error: Max retries exceeded'

# %%
no_language_repos = df[df['language'].isnull()]
no_language_repos.head()
# Out:
#                           name
# 1                   NetCodeTop  \
# 4   JavaScriptCodingChallenges
# 23         awesome-playgrounds
# 25                    xingtian
# 29              90DaysOfDevOps
#
#                                                   url
# 1         https://github.com/bianchenglequ/NetCodeTop  \
# 4   https://github.com/jahidulislamzim/JavaScriptC...
# 23  https://github.com/marcosnils/awesome-playgrounds
# 25                 https://github.com/hjyvip/xingtian
# 29        https://github.com/rajani103/90DaysOfDevOps
#
#                                           description  stars
# 1              收集GitHub上有关.Net、.NetCore有趣、有用、热门的开源项目。    589  \
# 4   Hello JavaScript code newbie! In this reposito...    221
# 23                        List of awesome playgrounds     85
# 25  VPN/proxy WIKI .Find the best VPN/proxy 免费的VPN...     77
# 29                                     90DaysOfDevOps     68
#
#               created_at language  forks  watchers  open_issues
# 1   2023-01-01T16:52:06Z      NaN    107       589            1  \
# 4   2023-01-01T14:04:36Z      NaN     41       221            0
# 23  2023-01-01T23:10:24Z      NaN      7        85            0
# 25  2023-01-01T12:12:01Z      NaN      7        77            0
# 29  2023-01-01T16:03:57Z      NaN     55        68            0
#
#               owner
# 1     bianchenglequ
# 4   jahidulislamzim
# 23       marcosnils
# 25           hjyvip
# 29        rajani103

# %% [markdown]
# ### NB : décommentez cet cell si vous étes interessait par les extentions des fichiers dans votre analyse

# %%
# # appliquer la fonction get_most_common_file_type sur la colonne url des lignes avec des valeurs manquantes dans la colonne language
# df.loc[df['language'].isnull(), 'language'] = df.loc[df['language'].isnull(), 'url'].apply(get_most_common_file_type)
# # afficher les lignes avec les indexes no_language_repos
# df.loc[no_language_repos.index].head()

# %%
# suppression des lignes avec des valeurs manquantes dans la colonne language
df = df.dropna(subset=['language'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 15600 entries, 0 to 18099
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   name         15600 non-null  object
#  1   url          15600 non-null  object
#  2   description  15600 non-null  object
#  3   stars        15600 non-null  int64
#  4   created_at   15600 non-null  object
#  5   language     15600 non-null  object
#  6   forks        15600 non-null  int64
#  7   watchers     15600 non-null  int64
#  8   open_issues  15600 non-null  int64
#  9   owner        15600 non-null  object
# dtypes: int64(4), object(6)
# memory usage: 1.3+ MB

# %% [markdown]
# -----------------------------------------------------------------------------------
# ## 3 - Traitement des valeurs doublents
# -----------------------------------------------------------------------------------

# %%
# rechereche des doubles
df[df.duplicated(subset=['url'])]
# Out:
# Empty DataFrame
# Columns: [name, url, description, stars, created_at, language, forks, watchers, open_issues, owner]
# Index: []

# %% [markdown]
# -----------------------------------------------------------------------------------
# ## 4 - Traduction de la langue des descriptions
# -----------------------------------------------------------------------------------

# %%
def translate_text(text):
    api_key = "your api key"
    url = "https://translation.googleapis.com/language/translate/v2"

    params = {
        "key": api_key,
        "q": text,
        "target": "en"  # Translate to English
    }

    try:
        response = requests.get(url, params=params)
        if response.status_code == 200:
            translated_text = response.json()["data"]["translations"][0]["translatedText"]
            return translated_text
        else:
            print("Translation failed. Status Code:", response.status_code)
            return None
    except requests.exceptions.RequestException as e:
        print("Translation request failed:", str(e))
        return None

# %%
# appliquer la fonction translate_text sur la colonne description
df['description'] = df['description'].apply(translate_text)

# %%
df.tail()
# Out:
#                  name                                                url
# 18094      nixstorefs        https://github.com/RaitoBezarius/nixstorefs  \
# 18095   20-PPT-Helper  https://github.com/Bistu-OSSDT-2023/20-PPT-Helper
# 18096         lighter               https://github.com/grabanton/lighter
# 18098       fedi-meta             https://github.com/alexisart/fedi-meta
# 18099  DreamDiffusion           https://github.com/bbaaii/DreamDiffusion
#
#                                              description  stars
# 18094  A userspace Nix store filesystem implementatio...      5  \
# 18095                      repository of 20 p p t helper      5
# 18096  Houdini package for fast and flexible hdri bas...      5
# 18098  Some tools to help protect the fediverse from ...      5
# 18099  Implementation of “DreamDiffusion: Generating ...      5
#
#                  created_at language  forks  watchers  open_issues
# 18094  2023-06-30T15:29:44Z      Nix      0         5            0  \
# 18095  2023-06-30T15:06:32Z     Java      0         5            0
# 18096  2023-06-30T06:37:25Z   Python      0         5            0
# 18098  2023-06-30T02:48:01Z   Python      1         5            0
# 18099  2023-06-30T08:50:08Z   Python      0         5            1
#
#                   owner
# 18094     RaitoBezarius
# 18095  Bistu-OSSDT-2023
# 18096         grabanton
# 18098         alexisart
# 18099            bbaaii

# %%
# sauvegarder le dataframe dans un fichier csv
df.to_csv('repositories2023-01-01_2023-06-30_100PerDay_cleaned.csv', index=False)
